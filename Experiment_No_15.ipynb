# %% [markdown]
# Experiment No.15
#
# Name:Pranav Menon\
# Batch : ENTC - B1\
# PRN No. : 25070123085
#
# Aim of the experiment : Data Normalization and Data Type Conversion

# %%
# Dataset Creation

import pandas as pd
import numpy as np

data = {
    'Product' : ['Laptop','Mobile','Tablet','Headphones','Smartwatch','Camera'],
    'Price' : [55000,20000,30000,2000,8000,45000],
    'Units Sold' : [25,60,35,80,50,15],
    'Discount' : [10,15,12,20,10,0]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Product  Price  Units Sold  Discount
# 0      Laptop  55000          25        10
# 1      Mobile  20000          60        15
# 2      Tablet  30000          35        12
# 3  Headphones   2000          80        20
# 4  Smartwatch   8000          50        10
# 5      Camera  45000          15         0

# %%
# Min - Max Normalisation
# Min - Max Normalisation for Price

df['Price_MinMax'] = (df['Price'] - df['Price'].min()) / (df['Price'].max() - df['Price'].min())
print(df[['Product','Price','Price_MinMax']])
# Out:
#       Product  Price  Price_MinMax
# 0      Laptop  55000      1.000000
# 1      Mobile  20000      0.339623
# 2      Tablet  30000      0.528302
# 3  Headphones   2000      0.000000
# 4  Smartwatch   8000      0.113208
# 5      Camera  45000      0.811321

# %%
# Normalise Multiple Columns

cols=['Price','Units Sold','Discount']
df_norm = (df[cols]-df[cols].min())/(df[cols].max() - df[cols].min())
print(df_norm)
# Out:
#       Price  Units Sold  Discount
# 0  1.000000    0.153846      0.50
# 1  0.339623    0.692308      0.75
# 2  0.528302    0.307692      0.60
# 3  0.000000    1.000000      1.00
# 4  0.113208    0.538462      0.50
# 5  0.811321    0.000000      0.00

# %%
# Z-Score Normalisation

df['Units ZScore'] = (df['Units Sold'] - df['Units Sold'].mean()) / df['Units Sold'].std()
print(df[['Product','Units Sold','Units ZScore']])
# Out:
#       Product  Units Sold  Units ZScore
# 0      Laptop          25     -0.799885
# 1      Mobile          60      0.660775
# 2      Tablet          35     -0.382554
# 3  Headphones          80      1.495437
# 4  Smartwatch          50      0.243443
# 5      Camera          15     -1.217216

# %%
# Decimal Scaling

df['Price_Decimal'] = df['Price'] / 100000
print(df[['Product','Price','Price_Decimal']])
# Out:
#       Product  Price  Price_Decimal
# 0      Laptop  55000           0.55
# 1      Mobile  20000           0.20
# 2      Tablet  30000           0.30
# 3  Headphones   2000           0.02
# 4  Smartwatch   8000           0.08
# 5      Camera  45000           0.45

# %%
# Decimal Scaling

df['Units_Decimal'] = df['Units Sold'] / 100
print(df[['Product','Price','Units_Decimal']])
# Out:
#       Product  Price  Units_Decimal
# 0      Laptop  55000           0.25
# 1      Mobile  20000           0.60
# 2      Tablet  30000           0.35
# 3  Headphones   2000           0.80
# 4  Smartwatch   8000           0.50
# 5      Camera  45000           0.15

# %%
# Decimal Scaling

df['Discounts_Decimal'] = df['Discount'] / 100
print(df[['Product','Price','Discounts_Decimal']])
# Out:
#       Product  Price  Discounts_Decimal
# 0      Laptop  55000               0.10
# 1      Mobile  20000               0.15
# 2      Tablet  30000               0.12
# 3  Headphones   2000               0.20
# 4  Smartwatch   8000               0.10
# 5      Camera  45000               0.00

# %%
# Data Creation

import pandas as pd
import numpy as np
data = {
'Order_ID':[101,102,103,104,105,106],
'Customer_Gender':['Male','Female','Female','Male','Female','Male'],
'Payment_Method':['UPI','Credit Card','Debit Card','COD','UPI','Debit Card'],
'Product_Category':['Electronics','Clothing','Home','Electronics','Beauty','Electronics'],
'City':['Pune','Mumbai','Delhi','Bangalore','Pune','Hyderabad'],
'Order_Value':[4500,2300,3200,5200,1800,4100]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card      Electronics  Hyderabad
#
#    Order_Value
# 0         4500
# 1         2300
# 2         3200
# 3         5200
# 4         1800
# 5         4100

# %%
# Label Encoding

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender_Label'] = le.fit_transform(df['Customer_Gender'])
df
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card      Electronics  Hyderabad
#
#    Order_Value  Gender_Label
# 0         4500             1
# 1         2300             0
# 2         3200             0
# 3         5200             1
# 4         1800             0
# 5         4100             1

# %%
# Label Encoding

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Payment_Method_Label'] = le.fit_transform(df['Payment_Method'])
df
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card      Electronics  Hyderabad
#
#    Order_Value  Gender_Label  Payment_Method_Label
# 0         4500             1                     3
# 1         2300             0                     1
# 2         3200             0                     2
# 3         5200             1                     0
# 4         1800             0                     3
# 5         4100             1                     2

# %%
# Label Encoding

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Product_Category_Label'] = le.fit_transform(df['Product_Category'])
df
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card      Electronics  Hyderabad
#
#    Order_Value  Gender_Label  Payment_Method_Label  Product_Category_Label
# 0         4500             1                     3                       2
# 1         2300             0                     1                       1
# 2         3200             0                     2                       3
# 3         5200             1                     0                       2
# 4         1800             0                     3                       0
# ...

# %%
# Label Encoding

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['City_Label'] = le.fit_transform(df['City'])
df
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card      Electronics  Hyderabad
#
#    Order_Value  Gender_Label  Payment_Method_Label  Product_Category_Label  \
# 0         4500             1                     3                       2
# 1         2300             0                     1                       1
# 2         3200             0                     2                       3
# 3         5200             1                     0                       2
# 4         1800             0                     3                       0
# ...

# %%
# One - Hot Coding

df_encoded = pd.get_dummies(df,columns=['Payment_Method'])
df_encoded
# Out:
#    Order_ID Customer_Gender Product_Category       City  Order_Value  \
# 0       101            Male      Electronics       Pune         4500
# 1       102          Female         Clothing     Mumbai         2300
# 2       103          Female             Home      Delhi         3200
# 3       104            Male      Electronics  Bangalore         5200
# 4       105          Female           Beauty       Pune         1800
# 5       106            Male      Electronics  Hyderabad         4100
#
#    Gender_Label  Payment_Method_Label  Product_Category_Label  City_Label  \
# 0             1                     3                       2           4
# 1             0                     1                       1           3
# 2             0                     2                       3           1
# 3             1                     0                       2           0
# 4             0                     3                       0           4
# ...

# %%
# One - Hot Coding

df_encoded = pd.get_dummies(df,columns=['Customer_Gender'])
df_encoded
# Out:
#    Order_ID Payment_Method Product_Category       City  Order_Value  \
# 0       101            UPI      Electronics       Pune         4500
# 1       102    Credit Card         Clothing     Mumbai         2300
# 2       103     Debit Card             Home      Delhi         3200
# 3       104            COD      Electronics  Bangalore         5200
# 4       105            UPI           Beauty       Pune         1800
# 5       106     Debit Card      Electronics  Hyderabad         4100
#
#    Gender_Label  Payment_Method_Label  Product_Category_Label  City_Label  \
# 0             1                     3                       2           4
# 1             0                     1                       1           3
# 2             0                     2                       3           1
# 3             1                     0                       2           0
# 4             0                     3                       0           4
# ...

# %%
# One - Hot Coding

df_encoded = pd.get_dummies(df,columns=['Product_Category'])
df_encoded
# Out:
#    Order_ID Customer_Gender Payment_Method       City  Order_Value  \
# 0       101            Male            UPI       Pune         4500
# 1       102          Female    Credit Card     Mumbai         2300
# 2       103          Female     Debit Card      Delhi         3200
# 3       104            Male            COD  Bangalore         5200
# 4       105          Female            UPI       Pune         1800
# 5       106            Male     Debit Card  Hyderabad         4100
#
#    Gender_Label  Payment_Method_Label  Product_Category_Label  City_Label  \
# 0             1                     3                       2           4
# 1             0                     1                       1           3
# 2             0                     2                       3           1
# 3             1                     0                       2           0
# 4             0                     3                       0           4
# ...

# %%
df_encoded = pd.get_dummies(df,columns=['City'])
df_encoded
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category  Order_Value  \
# 0       101            Male            UPI      Electronics         4500
# 1       102          Female    Credit Card         Clothing         2300
# 2       103          Female     Debit Card             Home         3200
# 3       104            Male            COD      Electronics         5200
# 4       105          Female            UPI           Beauty         1800
# 5       106            Male     Debit Card      Electronics         4100
#
#    Gender_Label  Payment_Method_Label  Product_Category_Label  City_Label  \
# 0             1                     3                       2           4
# 1             0                     1                       1           3
# 2             0                     2                       3           1
# 3             1                     0                       2           0
# 4             0                     3                       0           4
# ...

# %%
# One - Hot Coding

df_encoded = pd.get_dummies(df,columns=['Order_Value'])
df_encoded
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category       City  \
# 0       101            Male            UPI      Electronics       Pune
# 1       102          Female    Credit Card         Clothing     Mumbai
# 2       103          Female     Debit Card             Home      Delhi
# 3       104            Male            COD      Electronics  Bangalore
# 4       105          Female            UPI           Beauty       Pune
# 5       106            Male     Debit Card      Electronics  Hyderabad
#
#    Gender_Label  Payment_Method_Label  Product_Category_Label  City_Label  \
# 0             1                     3                       2           4
# 1             0                     1                       1           3
# 2             0                     2                       3           1
# 3             1                     0                       2           0
# 4             0                     3                       0           4
# ...

# %%
# Dummy Coding

df_encoded = pd.get_dummies(df,columns=['Payment_Method'],drop_first=True)
df_encoded
# Out:
#    Order_ID Customer_Gender Product_Category       City  Order_Value  \
# 0       101            Male      Electronics       Pune         4500
# 1       102          Female         Clothing     Mumbai         2300
# 2       103          Female             Home      Delhi         3200
# 3       104            Male      Electronics  Bangalore         5200
# 4       105          Female           Beauty       Pune         1800
# 5       106            Male      Electronics  Hyderabad         4100
#
#    Gender_Label  Payment_Method_Label  Product_Category_Label  City_Label  \
# 0             1                     3                       2           4
# 1             0                     1                       1           3
# 2             0                     2                       3           1
# 3             1                     0                       2           0
# 4             0                     3                       0           4
# ...

# %%
# Dummy Coding

df_encoded = pd.get_dummies(df,columns=['Customer_Gender'],drop_first=True)
df_encoded
# Out:
#    Order_ID Payment_Method Product_Category       City  Order_Value  \
# 0       101            UPI      Electronics       Pune         4500
# 1       102    Credit Card         Clothing     Mumbai         2300
# 2       103     Debit Card             Home      Delhi         3200
# 3       104            COD      Electronics  Bangalore         5200
# 4       105            UPI           Beauty       Pune         1800
# 5       106     Debit Card      Electronics  Hyderabad         4100
#
#    Gender_Label  Payment_Method_Label  Product_Category_Label  City_Label  \
# 0             1                     3                       2           4
# 1             0                     1                       1           3
# 2             0                     2                       3           1
# 3             1                     0                       2           0
# 4             0                     3                       0           4
# ...

# %%
# Dummy Coding

df_encoded = pd.get_dummies(df,columns=['Product_Category'],drop_first=True)
df_encoded
# Out:
#    Order_ID Customer_Gender Payment_Method       City  Order_Value  \
# 0       101            Male            UPI       Pune         4500
# 1       102          Female    Credit Card     Mumbai         2300
# 2       103          Female     Debit Card      Delhi         3200
# 3       104            Male            COD  Bangalore         5200
# 4       105          Female            UPI       Pune         1800
# 5       106            Male     Debit Card  Hyderabad         4100
#
#    Gender_Label  Payment_Method_Label  Product_Category_Label  City_Label  \
# 0             1                     3                       2           4
# 1             0                     1                       1           3
# 2             0                     2                       3           1
# 3             1                     0                       2           0
# 4             0                     3                       0           4
# ...

# %%
# Dummy Coding

df_encoded = pd.get_dummies(df,columns=['City'],drop_first=True)
df_encoded
# Out:
#    Order_ID Customer_Gender Payment_Method Product_Category  Order_Value  \
# 0       101            Male            UPI      Electronics         4500
# 1       102          Female    Credit Card         Clothing         2300
# 2       103          Female     Debit Card             Home         3200
# 3       104            Male            COD      Electronics         5200
# 4       105          Female            UPI           Beauty         1800
# 5       106            Male     Debit Card      Electronics         4100
#
#    Gender_Label  Payment_Method_Label  Product_Category_Label  City_Label  \
# 0             1                     3                       2           4
# 1             0                     1                       1           3
# 2             0                     2                       3           1
# 3             1                     0                       2           0
# 4             0                     3                       0           4
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/amazon_products_dataset.csv')
df
# Out:
#    Product_ID                 Product_Name  Price  Rating  Reviews  Units_Sold
# 0        P101               Wireless Mouse    799     4.3     1520         350
# 1        P102            Bluetooth Speaker   1499     4.5      980         220
# 2        P103                 USB Keyboard    699     4.1      870         180
# 3        P104               Gaming Headset   2499     4.6     2100         410
# 4        P105                   Smartwatch   3999     4.4     3050         520
# 5        P106                   Power Bank   1199     4.2     1750         390
# 6        P107                 Laptop Stand    899     4.0      620         140
# 7        P108                       Webcam   1899     4.3     1120         260
# 8        P109                 Portable SSD   5499     4.7     1850         330
# 9        P110             Wireless Charger    999     4.2      760         190
# 10       P111  Noise Cancelling Headphones   7999     4.6     4200         610
# ...

# %%
# Min - Max Normalisation
# Min - Max Normalisation for Price

df['Price_MinMax'] = (df['Price'] - df['Price'].min()) / (df['Price'].max() - df['Price'].min())
print(df[['Product_ID','Price','Price_MinMax']])
# Out:
#    Product_ID  Price  Price_MinMax
# 0        P101    799      0.020243
# 1        P102   1499      0.048583
# 2        P103    699      0.016194
# 3        P104   2499      0.089069
# 4        P105   3999      0.149798
# 5        P106   1199      0.036437
# 6        P107    899      0.024291
# 7        P108   1899      0.064777
# 8        P109   5499      0.210526
# 9        P110    999      0.028340
# 10       P111   7999      0.311741
# 11       P112   4599      0.174089
# 12       P113   1599      0.052632
# 13       P114    699      0.016194
# 14       P115    899      0.024291
# 15       P116   6499      0.251012
# 16       P117   1199      0.036437
# 17       P118   1999      0.068826
# 18       P119   2999      0.109312
# 19       P120   1299      0.040486
# 20       P121    499      0.008097
# 21       P122   2499      0.089069
# 22       P123   8999      0.352227
# 23       P124    799      0.020243
# 24       P125   3499      0.129555
# 25       P126   4599      0.174089
# ...

# %%
# Normalise Multiple Columns

cols=['Rating','Reviews',	'Units_Sold']
df_norm = (df[cols]-df[cols].min())/(df[cols].max() - df[cols].min())
print(df_norm)
# Out:
#       Rating   Reviews  Units_Sold
# 0   0.428571  0.291005    0.518519
# 1   0.714286  0.148148    0.277778
# 2   0.142857  0.119048    0.203704
# 3   0.857143  0.444444    0.629630
# 4   0.571429  0.695767    0.833333
# 5   0.285714  0.351852    0.592593
# 6   0.000000  0.052910    0.129630
# 7   0.428571  0.185185    0.351852
# 8   1.000000  0.378307    0.481481
# 9   0.285714  0.089947    0.222222
# 10  0.857143  1.000000    1.000000
# 11  0.714286  0.444444    0.407407
# 12  0.571429  0.232804    0.500000
# 13  0.142857  0.031746    0.092593
# 14  0.285714  0.119048    0.240741
# 15  0.857143  0.497354    0.444444
# 16  0.428571  0.089947    0.259259
# 17  0.571429  0.312169    0.648148
# 18  0.714286  0.814815    0.851852
# 19  0.428571  0.148148    0.351852
# 20  0.000000  0.000000    0.148148
# 21  0.571429  0.272487    0.444444
# 22  0.857143  0.219577    0.185185
# 23  0.285714  0.079365    0.259259
# 24  0.714286  0.444444    0.592593
# 25  0.571429  0.148148    0.166667
# ...

# %%
# Z-Score Normalisation

df['Units ZScore'] = (df['Units_Sold'] - df['Units_Sold'].mean()) / df['Units_Sold'].std()
print(df[['Product_ID','Units_Sold','Units ZScore']])
# Out:
#    Product_ID  Units_Sold  Units ZScore
# 0        P101         350      0.812282
# 1        P102         220     -0.260855
# 2        P103         180     -0.591051
# 3        P104         410      1.307576
# 4        P105         520      2.215615
# 5        P106         390      1.142478
# 6        P107         140     -0.921247
# 7        P108         260      0.069341
# 8        P109         330      0.647184
# 9        P110         190     -0.508502
# 10       P111         610      2.958556
# 11       P112         290      0.316988
# 12       P113         340      0.729733
# 13       P114         120     -1.086345
# 14       P115         200     -0.425953
# 15       P116         310      0.482086
# 16       P117         210     -0.343404
# 17       P118         420      1.390125
# 18       P119         530      2.298164
# 19       P120         260      0.069341
# 20       P121         150     -0.838698
# 21       P122         310      0.482086
# ...

# %%
# Decimal Scaling

df['Units_Decimal'] = df['Units_Sold'] / 100
print(df[['Product_ID','Units_Decimal']])
# Out:
#    Product_ID  Units_Decimal
# 0        P101            3.5
# 1        P102            2.2
# 2        P103            1.8
# 3        P104            4.1
# 4        P105            5.2
# 5        P106            3.9
# 6        P107            1.4
# 7        P108            2.6
# 8        P109            3.3
# 9        P110            1.9
# 10       P111            6.1
# 11       P112            2.9
# 12       P113            3.4
# 13       P114            1.2
# 14       P115            2.0
# 15       P116            3.1
# 16       P117            2.1
# 17       P118            4.2
# 18       P119            5.3
# 19       P120            2.6
# 20       P121            1.5
# 21       P122            3.1
# 22       P123            1.7
# 23       P124            2.1
# 24       P125            3.9
# 25       P126            1.6
# 26       P127            1.4
# 27       P128            2.7
# 28       P129            2.4
# 29       P130            2.6
# 30       P131            2.0
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/Student-Dataset.csv')
df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage Placement_Status  Salary
# 0                     92           Placed  450000
# 1                     85       Not Placed       0
# 2                     96           Placed  550000
# 3                     78       Not Placed       0
# 4                     88           Placed  480000
# ...

# %%
# Label Encoding

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender_Label'] = le.fit_transform(df['Gender'])
df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage Placement_Status  Salary  Gender_Label
# 0                     92           Placed  450000             0
# 1                     85       Not Placed       0             1
# 2                     96           Placed  550000             0
# 3                     78       Not Placed       0             1
# ...

# %%
# One - Hot Coding

df_encoded = pd.get_dummies(df,columns=['CGPA'])
df_encoded
# Out:
#    Roll_No  Gender  Department  Number_of_Backlogs  Attendance_Percentage  \
# 0      101  Female    Computer                   0                     92
# 1      102    Male          IT                   1                     85
# 2      103  Female        ENTC                   0                     96
# 3      104    Male  Mechanical                   2                     78
# 4      105  Female    Computer                   0                     88
# 5      106    Male       Civil                   3                     72
# 6      107  Female          IT                   0                     91
# 7      108    Male    Computer                   1                     80
# 8      109  Female        ENTC                   0                     84
# 9      110    Male  Mechanical                   2                     76
#
#   Placement_Status  Salary  Gender_Label  CGPA_6.5  CGPA_6.8  CGPA_7.0  \
# 0           Placed  450000             0     False     False     False
# ...

# %%
# Dummy Coding

df_encoded = pd.get_dummies(df,columns=['Attendance_Percentage'],drop_first=True)
df_encoded
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs Placement_Status  \
# 0      101  Female    Computer   8.2                   0           Placed
# 1      102    Male          IT   7.5                   1       Not Placed
# 2      103  Female        ENTC   9.1                   0           Placed
# 3      104    Male  Mechanical   6.8                   2       Not Placed
# 4      105  Female    Computer   8.7                   0           Placed
# 5      106    Male       Civil   7.2                   3       Not Placed
# 6      107  Female          IT   8.9                   0           Placed
# 7      108    Male    Computer   6.5                   1       Not Placed
# 8      109  Female        ENTC   7.8                   0           Placed
# 9      110    Male  Mechanical   7.0                   2       Not Placed
#
#    Salary  Gender_Label  Attendance_Percentage_76  Attendance_Percentage_78  \
# 0  450000             0                     False                     False
# ...
